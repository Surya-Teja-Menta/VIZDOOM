# %%
from vizdoom import *
import time,random
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2
from stable_baselines3 import PPO

import numpy as np

# %%
game=DoomGame()
game.load_config('scenarios/take_cover.cfg')
game.init()

# %%
game.close()

# %%
actions = np.identity(2, dtype=np.uint8)
actions
# Out:
# array([[1, 0],
#        [0, 1]], dtype=uint8)

# %%
game.get_available_buttons_size()
# Out:
# 2

# %%
c.shape
# Out:
# (3, 450, 800)

# %%
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        # print('reward:', reward) 
        time.sleep(0.5)
    print('Result:', game.get_total_reward())
    time.sleep(0.2)
# Out:
# Result: 317.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_66688/3476659084.py in <module>
#      15         # Print rewward
#      16         # print('reward:', reward)
# ---> 17         time.sleep(0.5)
#      18     print('Result:', game.get_total_reward())
#      19     time.sleep(0.2)
#
# KeyboardInterrupt:

# %% [markdown]
# class VizDoomGym(Env):
#     # Function that is called when we start the env
#     def __init__(self, render=False, config='scenarios/health_gathering.cfg'):
#         # Inherit from Env
#         super().__init__()
#         # Setup the game
#         self.game = DoomGame()
#         self.game.load_config(config)
#
#         # Render frame logic
#         self.game.set_window_visible(render)
#         # Start the game
#         self.game.init()
#
#         # Create the action space and observation space
#         self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
#         self.action_space = Discrete(3)
#
#         # Game variables: HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
#         #self.damage_taken = 0
#         #self.hitcount = 0
#         self.health = 100 ## CHANGED
#         self.neg = 0.5
#         self.pos = 50
#
#     # This is how we take a step in the environment
#     def step(self, action):
#         # Specify action and take step
#         actions = np.identity(3)
#         reward = self.game.make_action(actions[action],1)
#
#         # Get all the other stuff we need to retun
#         if self.game.get_state():
#             state = self.game.get_state().screen_buffer
#             state = self.grayscale(state)
#             health = self.game.get_state().game_variables[0]
#             health_delta=self.health-health
#             self.health=health
#             if health_delta<0:
#                 reward=reward+self.pos
#             else:
#                 reward=reward-self.neg
#
#             info = health
#
#         else:
#             state = np.zeros(self.observation_space.shape)
#             info = 0
#
#         info = {"info":info}
#         done = self.game.is_episode_finished()
#
#         return state, reward, done, info
#
#
#     # Define how to render the game or environment
#     def render():
#         pass
#
#     # What happens when we start a new game
#     def reset(self):
#         self.game.new_episode()
#         state = self.game.get_state().screen_buffer
#         return self.grayscale(state)
#
#     # Grayscale the game frame and resize it
#     def grayscale(self, observation):
#         gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
#         resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
#         state = np.reshape(resize, (100,160,1))
#         return state
#
#     # Call to close down the game
#     def close(self):
#         self.game.close()

# %% [markdown]
# class VizDoomGym(Env):
#     # Function that is called when we start the env
#     def __init__(self, render=False, config='scenarios/take_cover.cfg'):
#         # Inherit from Env
#         super().__init__()
#         # Setup the game
#         self.game = DoomGame()
#         self.game.load_config(config)
#
#         # Render frame logic
#         self.game.set_window_visible(render)
#         # Start the game
#         self.game.init()
#
#         # Create the action space and observation space
#         self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
#         self.action_space = Discrete(2)
#
#         # Game variables: HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
#         #self.damage_taken = 0
#         self.hitcount = 0
#
#
#     # This is how we take a step in the environment
#     def step(self, action):
#         # Specify action and take step
#         actions = np.identity(3)
#         reward = self.game.make_action(actions[action],1)
#
#         # Get all the other stuff we need to retun
#         if self.game.get_state():
#             state = self.game.get_state().screen_buffer
#             state = self.grayscale(state)
#             info = self.game.get_state().game_variables[0]
#
#         else:
#             state = np.zeros(self.observation_space.shape)
#             info = 0
#
#         info = {"info":info}
#         done = self.game.is_episode_finished()
#
#         return state, reward, done, info
#
#
#     # Define how to render the game or environment
#     def render():
#         pass
#
#     # What happens when we start a new game
#     def reset(self):
#         self.game.new_episode()
#         state = self.game.get_state().screen_buffer
#         return self.grayscale(state)
#
#     # Grayscale the game frame and resize it
#     def grayscale(self, observation):
#         gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
#         resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
#         state = np.reshape(resize, (100,160,1))
#         return state
#
#     # Call to close down the game
#     def close(self):
#         self.game.close()

# %%
env = VizDoomGym(render=True)
state = env.reset()

from stable_baselines3.common import env_checker
env_checker.check_env(env)
env.close()

# %%
env.close()

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_take_cover'
LOG_DIR = './logs/log_take_cover'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
from stable_baselines3 import PPO
env = VizDoomGym(config='scenarios/take_cover_1.cfg')
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.00006, n_steps=8192)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_take_cover/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | 353      |
# | time/              |          |
# |    fps             | 176      |
# |    iterations      | 1        |
# |    time_elapsed    | 46       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | 346         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 2           |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013604157 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 6e-05       |
# |    loss                 | 3.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000606   |
# |    value_loss           | 6.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 339         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 3           |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009993519 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 2.05        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 14.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 327          |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 4            |
# |    time_elapsed         | 870          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0071041924 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.663       |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 25.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000114    |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | 304          |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 5            |
# |    time_elapsed         | 1128         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0051123803 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 42.6         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.000439     |
# |    value_loss           | 29.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 309        |
# |    ep_rew_mean          | 309        |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 6          |
# |    time_elapsed         | 1438       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00589912 |
# |    clip_fraction        | 0.0663     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.619     |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 6e-05      |
# |    loss                 | 12.9       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0011    |
# |    value_loss           | 29.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 323         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 7           |
# |    time_elapsed         | 1723        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011018829 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 10.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000862   |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 8           |
# |    time_elapsed         | 2039        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013062614 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 11.8        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 355         |
# |    ep_rew_mean          | 355         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 9           |
# |    time_elapsed         | 2362        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013796713 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 16.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 65.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 375          |
# |    ep_rew_mean          | 375          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 10           |
# |    time_elapsed         | 2684         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0135259675 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 28.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 9.37e-05     |
# |    value_loss           | 60.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 369         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 11          |
# |    time_elapsed         | 2931        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009231957 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 32.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000648    |
# |    value_loss           | 74.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 369         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 12          |
# |    time_elapsed         | 3155        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011158719 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 47.8        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | 385         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 13          |
# |    time_elapsed         | 3379        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013515401 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 12.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.000993    |
# |    value_loss           | 76          |
# -----------------------------------------

# %%
# Out:
# Logging to ./logs/log_take_cover/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    fps             | 137      |
# |    iterations      | 1        |
# |    time_elapsed    | 59       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 2           |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008156296 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 25.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00055     |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 3           |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008585968 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 12.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 46.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 225          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 4            |
# |    time_elapsed         | 1046         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0056458646 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 40.8         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000847    |
# |    value_loss           | 42.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 233        |
# |    ep_rew_mean          | 233        |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 5          |
# |    time_elapsed         | 1374       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00596098 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.628     |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 6e-05      |
# |    loss                 | 12.2       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -6.43e-05  |
# |    value_loss           | 37.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 6           |
# |    time_elapsed         | 1701        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009108694 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 25.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 31.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 7           |
# |    time_elapsed         | 2028        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007887035 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 4.94        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 8            |
# |    time_elapsed         | 2354         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0067724437 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 5.3          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000701     |
# |    value_loss           | 38.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 295         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 9           |
# |    time_elapsed         | 2680        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008683238 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 15.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00013    |
# |    value_loss           | 54.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | 314         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 10          |
# |    time_elapsed         | 3005        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008311941 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 45.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000343    |
# |    value_loss           | 89.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 344          |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 11           |
# |    time_elapsed         | 3331         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0129388925 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 22.1         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -8.99e-05    |
# |    value_loss           | 59.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | 346         |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 12          |
# |    time_elapsed         | 3655        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011438163 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 15.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00046     |
# |    value_loss           | 55.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | 356         |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 13          |
# |    time_elapsed         | 3979        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008314913 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 20          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00023    |
# |    value_loss           | 64.1        |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/take_cover_2.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_take_cover/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    fps             | 208      |
# |    iterations      | 1        |
# |    time_elapsed    | 39       |
# |    total_timesteps | 8192     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 2            |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0046893964 |
# |    clip_fraction        | 0.0969       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 33.8         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000398    |
# |    value_loss           | 93.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 3           |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009198792 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 48.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 4           |
# |    time_elapsed         | 710         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007980406 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 49.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000517   |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 5           |
# |    time_elapsed         | 932         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008507335 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 30.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 85.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 292         |
# |    ep_rew_mean          | 292         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 6           |
# |    time_elapsed         | 1154        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011660943 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 14          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 73.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 7           |
# |    time_elapsed         | 1374        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009627733 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 62.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 74.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 314          |
# |    ep_rew_mean          | 314          |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 8            |
# |    time_elapsed         | 1595         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0095318165 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 42.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 80           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 9           |
# |    time_elapsed         | 1816        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008155041 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 26.9        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000306   |
# |    value_loss           | 58.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 329          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 10           |
# |    time_elapsed         | 2037         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0073174527 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 6e-05        |
# |    loss                 | 25.5         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000463     |
# |    value_loss           | 75.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 338         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 11          |
# |    time_elapsed         | 2258        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008428092 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 28.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000466    |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 12          |
# |    time_elapsed         | 2479        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012590125 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 12.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 53.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 336         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 13          |
# |    time_elapsed         | 2701        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.016207263 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 46.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 66.6        |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/take_cover_3.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_take_cover/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    fps             | 224      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 293         |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009693933 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 25.4        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00101     |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 308         |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 3           |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012237292 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 34.1        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000867    |
# |    value_loss           | 65.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 4           |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011292221 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 12.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00193     |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 326         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 5           |
# |    time_elapsed         | 930         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011959182 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 24.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.000755    |
# |    value_loss           | 55.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 6           |
# |    time_elapsed         | 1154        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007341029 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 43.3        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000289   |
# |    value_loss           | 70.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 7           |
# |    time_elapsed         | 1380        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009846748 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 33          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000986    |
# |    value_loss           | 61          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 310        |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 8          |
# |    time_elapsed         | 1604       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00824479 |
# |    clip_fraction        | 0.0922     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.61      |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 6e-05      |
# |    loss                 | 28.3       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.000201   |
# |    value_loss           | 67.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 315          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 9            |
# |    time_elapsed         | 1833         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0060622124 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 80.4         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00104      |
# |    value_loss           | 82.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 10          |
# |    time_elapsed         | 2088        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012852326 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 32.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0035      |
# |    value_loss           | 61.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 302          |
# |    ep_rew_mean          | 302          |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 11           |
# |    time_elapsed         | 2349         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0106108375 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 17.9         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00116      |
# |    value_loss           | 65.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 12          |
# |    time_elapsed         | 2615        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009364946 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 14.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00138     |
# |    value_loss           | 87.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 13          |
# |    time_elapsed         | 2933        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008701391 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 21.8        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00176     |
# |    value_loss           | 72.5        |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/take_cover_4.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_take_cover/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 314      |
# | time/              |          |
# |    fps             | 148      |
# |    iterations      | 1        |
# |    time_elapsed    | 55       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 321         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 2           |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009109691 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 27.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 54.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 317          |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 3            |
# |    time_elapsed         | 724          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0055542034 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.718        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 12.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 56.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 4           |
# |    time_elapsed         | 1068        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010524949 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 25.6        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00228     |
# |    value_loss           | 68.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | 312         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 5           |
# |    time_elapsed         | 1415        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010960477 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 81.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.000688    |
# |    value_loss           | 67.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 304         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 6           |
# |    time_elapsed         | 1770        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009605184 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 16.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00133     |
# |    value_loss           | 63.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | 299         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 7           |
# |    time_elapsed         | 2028        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011611842 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 15.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00225     |
# |    value_loss           | 69.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | 289         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 8           |
# |    time_elapsed         | 2287        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010349573 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 11.5        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 60.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 9            |
# |    time_elapsed         | 2546         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0099001285 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 55.1         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00163      |
# |    value_loss           | 67.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 10          |
# |    time_elapsed         | 2806        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010731784 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 26.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00305     |
# |    value_loss           | 92.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 11          |
# |    time_elapsed         | 3064        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010378637 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.474      |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 10.7        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00186     |
# |    value_loss           | 74.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 257         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 12          |
# |    time_elapsed         | 3324        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010845435 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 72.5        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00122     |
# |    value_loss           | 72.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 13          |
# |    time_elapsed         | 3584        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009748638 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 49.3        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.000751    |
# |    value_loss           | 61.6        |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/take_cover_5.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_take_cover/PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    fps             | 187      |
# |    iterations      | 1        |
# |    time_elapsed    | 43       |
# |    total_timesteps | 8192     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 125        |
# |    ep_rew_mean          | 125        |
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 2          |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01603201 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.422     |
# |    explained_variance   | 0.644      |
# |    learning_rate        | 6e-05      |
# |    loss                 | 31.7       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.000671   |
# |    value_loss           | 85.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 3           |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009519013 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.38       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 19          |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00207     |
# |    value_loss           | 67.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 4            |
# |    time_elapsed         | 827          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0076505477 |
# |    clip_fraction        | 0.0815       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.374       |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 42.4         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -7.53e-05    |
# |    value_loss           | 59.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 5           |
# |    time_elapsed         | 1087        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008127913 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 22.7        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.000447    |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 6           |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008050816 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 14.3        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00221     |
# |    value_loss           | 45.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 7            |
# |    time_elapsed         | 1609         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0061814985 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.395       |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 19.3         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.00121      |
# |    value_loss           | 41.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 8           |
# |    time_elapsed         | 1869        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008493228 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 16          |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00046     |
# |    value_loss           | 45.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 9            |
# |    time_elapsed         | 2129         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0072806063 |
# |    clip_fraction        | 0.0899       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.397       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 5.67         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.000473     |
# |    value_loss           | 43.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 10          |
# |    time_elapsed         | 2389        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009378605 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 18.8        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.00156     |
# |    value_loss           | 38          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 11          |
# |    time_elapsed         | 2650        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011058927 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 14.9        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.000454    |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 12          |
# |    time_elapsed         | 2874        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006092149 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 9.02        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.0019      |
# |    value_loss           | 32.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 13           |
# |    time_elapsed         | 3114         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0066746166 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 6e-05        |
# |    loss                 | 16           |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.000449    |
# |    value_loss           | 31.9         |
# ------------------------------------------

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_take_cover/PPO_8
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    fps             | 222      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009768598 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 19.8        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00035    |
# |    value_loss           | 47.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 163        |
# |    ep_rew_mean          | 163        |
# | time/                   |            |
# |    fps                  | 50         |
# |    iterations           | 3          |
# |    time_elapsed         | 482        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00907101 |
# |    clip_fraction        | 0.0969     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.397     |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 6e-05      |
# |    loss                 | 14.7       |
# |    n_updates            | 670        |
# |    policy_gradient_loss | 0.00196    |
# |    value_loss           | 40         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 4           |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010435626 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.387      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 9.7         |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.0021      |
# |    value_loss           | 43.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 5           |
# |    time_elapsed         | 927         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012903361 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.395      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 18.4        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.00181     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 6           |
# |    time_elapsed         | 1149        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012501292 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 12.3        |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.000674   |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 7           |
# |    time_elapsed         | 1376        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012933521 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 11.8        |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.00372     |
# |    value_loss           | 49.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 8           |
# |    time_elapsed         | 1599        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012097965 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 10.5        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.000116    |
# |    value_loss           | 44.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 9           |
# |    time_elapsed         | 1822        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009207834 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.354      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 10.4        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | 0.000353    |
# |    value_loss           | 44.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 10          |
# |    time_elapsed         | 2053        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010714849 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 5.75        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 31.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 11          |
# |    time_elapsed         | 2278        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012889499 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 13.4        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 0.0024      |
# |    value_loss           | 40.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 12          |
# |    time_elapsed         | 2502        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009442112 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 6e-05       |
# |    loss                 | 16          |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.000233    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 13          |
# |    time_elapsed         | 2725        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011087071 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 6e-05       |
# |    loss                 | 8.26        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | 0.00142     |
# |    value_loss           | 35.2        |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/deadly_corridor_s2.cfg')
model.set_env(env)
model.learn(total_timesteps=200000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_corridor2/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 462      |
# | time/              |          |
# |    fps             | 202      |
# |    iterations      | 1        |
# |    time_elapsed    | 40       |
# |    total_timesteps | 8192     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.6         |
# |    ep_rew_mean          | 479          |
# | time/                   |              |
# |    fps                  | 51           |
# |    iterations           | 2            |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0061990884 |
# |    clip_fraction        | 0.243        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.378        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.21e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.0048       |
# |    value_loss           | 2.65e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.8        |
# |    ep_rew_mean          | 503         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 3           |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006928308 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00458     |
# |    value_loss           | 2.48e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.1         |
# |    ep_rew_mean          | 507          |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 4            |
# |    time_elapsed         | 889          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0061740912 |
# |    clip_fraction        | 0.238        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.21e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00323      |
# |    value_loss           | 2.39e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.3         |
# |    ep_rew_mean          | 536          |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 5            |
# |    time_elapsed         | 1197         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0039995657 |
# |    clip_fraction        | 0.242        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.37e+04     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00315      |
# |    value_loss           | 2.42e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.9        |
# |    ep_rew_mean          | 507         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 6           |
# |    time_elapsed         | 1506        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008811132 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.31e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00521     |
# |    value_loss           | 2.36e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35           |
# |    ep_rew_mean          | 510          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 7            |
# |    time_elapsed         | 1775         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0071430015 |
# |    clip_fraction        | 0.292        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.14e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.005        |
# |    value_loss           | 2.24e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.4         |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 8            |
# |    time_elapsed         | 2006         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0064591467 |
# |    clip_fraction        | 0.288        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.38e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00647      |
# |    value_loss           | 2.11e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | 482          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 9            |
# |    time_elapsed         | 2238         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0070719654 |
# |    clip_fraction        | 0.254        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.17e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00399      |
# |    value_loss           | 2.22e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.7        |
# |    ep_rew_mean          | 502         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 10          |
# |    time_elapsed         | 2485        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004025997 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 7.46e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00598     |
# |    value_loss           | 2.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.5        |
# |    ep_rew_mean          | 558         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 11          |
# |    time_elapsed         | 2757        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004412335 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 7.71e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00464     |
# |    value_loss           | 2.3e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.3         |
# |    ep_rew_mean          | 565          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 12           |
# |    time_elapsed         | 3030         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0050399797 |
# |    clip_fraction        | 0.261        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.912       |
# |    explained_variance   | 0.53         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00495      |
# |    value_loss           | 2.23e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | 611          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 13           |
# |    time_elapsed         | 3306         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0059649805 |
# |    clip_fraction        | 0.227        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.16e+04     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.0047       |
# |    value_loss           | 2.24e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | 573          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 14           |
# |    time_elapsed         | 3584         |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0052660494 |
# |    clip_fraction        | 0.222        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.87e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00423      |
# |    value_loss           | 2.37e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.6         |
# |    ep_rew_mean          | 635          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 15           |
# |    time_elapsed         | 3865         |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0069028684 |
# |    clip_fraction        | 0.22         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.516        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.49e+03     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00426      |
# |    value_loss           | 2.38e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.9        |
# |    ep_rew_mean          | 707         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 16          |
# |    time_elapsed         | 4148        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004622489 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.26e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00493     |
# |    value_loss           | 2.33e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.1       |
# |    ep_rew_mean          | 773        |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 17         |
# |    time_elapsed         | 4433       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.00484559 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.639     |
# |    explained_variance   | 0.5        |
# |    learning_rate        | 1e-05      |
# |    loss                 | 1.04e+04   |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.00513    |
# |    value_loss           | 2.41e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | 787          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 18           |
# |    time_elapsed         | 4720         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0047290875 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.94e+03     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | 0.00327      |
# |    value_loss           | 2.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.2         |
# |    ep_rew_mean          | 775          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 19           |
# |    time_elapsed         | 5006         |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0052768677 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.451        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.59e+04     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.00348      |
# |    value_loss           | 2.58e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.1         |
# |    ep_rew_mean          | 841          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 20           |
# |    time_elapsed         | 5293         |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0040760124 |
# |    clip_fraction        | 0.0964       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.38e+04     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | 0.0033       |
# |    value_loss           | 2.44e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.6        |
# |    ep_rew_mean          | 825         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 21          |
# |    time_elapsed         | 5581        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002954442 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.404      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.98e+04    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00353     |
# |    value_loss           | 2.68e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.6         |
# |    ep_rew_mean          | 838          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 22           |
# |    time_elapsed         | 5904         |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0021899203 |
# |    clip_fraction        | 0.0866       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.87e+03     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.00204      |
# |    value_loss           | 2.82e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.8         |
# |    ep_rew_mean          | 816          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 23           |
# |    time_elapsed         | 6227         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0026842167 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.35e+04     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 0.00246      |
# |    value_loss           | 2.79e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.3         |
# |    ep_rew_mean          | 827          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 24           |
# |    time_elapsed         | 6571         |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0033346894 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.373       |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.17e+04     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.00266      |
# |    value_loss           | 2.81e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | 862         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 25          |
# |    time_elapsed         | 6942        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.003930889 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.342      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.00217     |
# |    value_loss           | 2.66e+04    |
# -----------------------------------------

# %%
env = VizDoomGym(config='scenarios/deadly_corridor_s3.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_corridor2/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.1     |
# |    ep_rew_mean     | 1.03e+03 |
# | time/              |          |
# |    fps             | 196      |
# |    iterations      | 1        |
# |    time_elapsed    | 41       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.8        |
# |    ep_rew_mean          | 993         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 2           |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.001553012 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.00202     |
# |    value_loss           | 2.96e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.9         |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 3            |
# |    time_elapsed         | 538          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0020786277 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.25e+04     |
# |    n_updates            | 670          |
# |    policy_gradient_loss | 0.000758     |
# |    value_loss           | 2.83e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.3         |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 4            |
# |    time_elapsed         | 787          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0008966766 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0917      |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.79e+04     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | 0.00169      |
# |    value_loss           | 2.76e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35           |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 5            |
# |    time_elapsed         | 1036         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0012623013 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0872      |
# |    explained_variance   | 0.38         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.56e+04     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | 0.0013       |
# |    value_loss           | 2.88e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.6         |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 6            |
# |    time_elapsed         | 1289         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0019418938 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0806      |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.56e+04     |
# |    n_updates            | 700          |
# |    policy_gradient_loss | 0.00162      |
# |    value_loss           | 2.92e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.8        |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 7           |
# |    time_elapsed         | 1537        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002983939 |
# |    clip_fraction        | 0.0139      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0649     |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.57e+04    |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.000922    |
# |    value_loss           | 3.03e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.3         |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 8            |
# |    time_elapsed         | 1786         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0010225781 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0659      |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.44e+04     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | 0.00123      |
# |    value_loss           | 2.79e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.2         |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 9            |
# |    time_elapsed         | 2034         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0007443589 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0533      |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.53e+04     |
# |    n_updates            | 730          |
# |    policy_gradient_loss | 0.00105      |
# |    value_loss           | 3.12e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 35.9          |
# |    ep_rew_mean          | 1.1e+03       |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 10            |
# |    time_elapsed         | 2282          |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00059571094 |
# |    clip_fraction        | 0.0114        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.0561       |
# |    explained_variance   | 0.342         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 1.5e+04       |
# |    n_updates            | 740           |
# |    policy_gradient_loss | 0.00122       |
# |    value_loss           | 3.31e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.4         |
# |    ep_rew_mean          | 996          |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 11           |
# |    time_elapsed         | 2530         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0026775263 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0374      |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.49e+04     |
# |    n_updates            | 750          |
# |    policy_gradient_loss | 0.000186     |
# |    value_loss           | 2.99e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37            |
# |    ep_rew_mean          | 1.1e+03       |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 12            |
# |    time_elapsed         | 2777          |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00072712114 |
# |    clip_fraction        | 0.00988       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.034        |
# |    explained_variance   | 0.361         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 1.65e+04      |
# |    n_updates            | 760           |
# |    policy_gradient_loss | 0.000962      |
# |    value_loss           | 2.94e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 33.9          |
# |    ep_rew_mean          | 1.01e+03      |
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 13            |
# |    time_elapsed         | 3025          |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00033951737 |
# |    clip_fraction        | 0.00568       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.0321       |
# |    explained_variance   | 0.38          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 1.27e+04      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | 0.000567      |
# |    value_loss           | 2.71e+04      |
# -------------------------------------------

# %%
from stable_baselines3 import PPO
#model.load('./train/train_corridor/best_model_580000.zip')
env = VizDoomGym(config='scenarios/deadly_corridor_s4.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/log_corridor2/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.9     |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    fps             | 218      |
# |    iterations      | 1        |
# |    time_elapsed    | 37       |
# |    total_timesteps | 8192     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24141/2111555211.py in <module>
#       3 env = VizDoomGym(config='scenarios/deadly_corridor_s4.cfg')
#       4 model.set_env(env)
# ----> 5 model.learn(total_timesteps=100000, callback=callback)
#
# ~/anaconda3/envs/ri/lib/python3.7/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     306             tb_log_name=tb_log_name,
#     307             eval_log_path=eval_log_path,
# --> 308             reset_num_timesteps=reset_num_timesteps,
#     309         )
#
# ~/anaconda3/envs/ri/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     268                 self.logger.dump(step=self.num_timesteps)
#     269
# --> 270             self.train()
#     271
#     272         callback.on_training_end()
#
# ~/anaconda3/envs/ri/lib/python3.7/site-packages/stable_baselines3/ppo/ppo.py in train(self)
#     257                 # Optimization step
#     258                 self.policy.optimizer.zero_grad()
# --> 259                 loss.backward()
#     260                 # Clip grad norm
#     261                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# ~/anaconda3/envs/ri/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/anaconda3/envs/ri/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
env = VizDoomGym(config='scenarios/deadly_corridor_s5.cfg')
model.set_env(env)
model.learn(total_timesteps=100000, callback=callback)

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
model = PPO.load('./train/train_corridor/DeadlyCorridor560k.zip')
#model = PPO.load('./train/train_corridor/DeadlyCorridor560k')

# %%
env = VizDoomGym(config='scenarios/deadly_corridor_s4.cfg')
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=20)
env.close()
mean_reward
# Out:
# /home/stm/anaconda3/envs/ri/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# 267.71122283935546

# %%
env = VizDoomGym(render=True)

for episode in range(20): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward
    print('Total Reward for episode {1} is {0}'.format(total_reward, episode))
    #time.sleep(0.5)
# Out:
# Total Reward for episode 0 is 358.0
# Total Reward for episode 1 is 448.0
# Total Reward for episode 2 is 530.0
# Total Reward for episode 3 is 423.0
# Total Reward for episode 4 is 451.0
# Total Reward for episode 5 is 400.0
# Total Reward for episode 6 is 383.0
# Total Reward for episode 7 is 604.0
# Total Reward for episode 8 is 326.0
# Total Reward for episode 9 is 353.0
# Total Reward for episode 10 is 301.0
# Total Reward for episode 11 is 301.0
# Total Reward for episode 12 is 667.0
# Total Reward for episode 13 is 455.0
# Total Reward for episode 14 is 421.0
# Total Reward for episode 15 is 404.0
# Total Reward for episode 16 is 414.0
# Total Reward for episode 17 is 237.0
# Total Reward for episode 18 is 437.0
# Total Reward for episode 19 is 416.0

# %%
model.predict(obs)
# Out:
# (1, None)

# %%
env.close()

# %%
random.randint(1,3)
# Out:
# 2

# %%
#basic

#Create a VizDoom environment.
class ViZDoomGym(Env):
    def __init__(self,render=False):
        super().__init__()
        #init Doomgame
        self.game = DoomGame()
        # Load the correct configuration
        self.game.load_config("../scenarios/basic.cfg")
        # Switching the Window render off/on
        self.game.set_window_visible(render)
        #start the game
        self.game.init()
        #Creating the Action and Observation Space
        self.action_space = Discrete(self.game.get_available_buttons_size())
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)

    def step(self,action):
        #Set the action
        actions=np.identity(self.game.get_available_buttons_size(),dtype=int)
        reward=self.game.make_action(actions[action],4)

        #things to return
        if self.game.get_state():
            state=self.game.get_state().screen_buffer
            state=self.graystate(state)
            ammo=self.game.get_state().game_variables[0]
            info=ammo
        else:
            state=np.zeros(self.observation_space.shape)
            info=0
        info={'info':info}
        #check if the game is over
        done=self.game.is_episode_finished()
        #return the state, reward, done, and info
        return state,reward,done,info

    def reset(self):
        self.game.new_episode()
        return self.graystate(self.game.get_state().screen_buffer)

    def graystate(self,observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        gray = cv2.resize(gray, (160, 100),interpolation=cv2.INTER_CUBIC)
        state=np.reshape(gray,(100,160,1))
        return state

    def close(self): 
        self.game.close()
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR,n_steps=8192)

model.load('models/train_basic/best_model_200000.zip')
